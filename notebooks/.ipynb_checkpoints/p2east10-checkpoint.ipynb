# %% [markdown]
# !pip install numpy pandas matplotlib seaborn keras tensorflow

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from sklearn.impute import SimpleImputer

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
import math
from sklearn.metrics import mean_squared_error
# Out:
# 2024-06-06 07:24:09.638278: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 07:24:09.920394: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 07:24:10.985785: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-06 07:24:13.539884: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# # Set the path to the directory containing the files
# path = '../data'

# # Create an empty list to store the names of the files
# files = []

# # Loop through all the files in the directory and add the file names to the list
# for file in os.listdir(path):
#     if file.endswith('.csv'):
#         files.append(os.path.join(path, file))

# # Use pandas to read all the files in the list into a single DataFrame
# df = pd.concat([pd.read_csv(file) for file in files], ignore_index=True)
df=pd.read_csv('./p2-east-1b.csv')
df.head
df.shape
# Out:
# (7182, 5)

# %%
df.head
# Out:
# <bound method NDFrame.head of       2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b    0.25
# 0     2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 1     2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# 2     2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2500
# 3     2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 4     2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# ...                         ...        ...         ...         ...     ...
# 7177  2017-04-26 15:26:03+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1613
# 7178  2017-04-26 15:25:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1610
# 7179  2017-04-26 15:23:21+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1616
# 7180  2017-04-26 15:22:21+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1623
# 7181  2017-04-26 15:21:19+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1620
#
# [7182 rows x 5 columns]>

# %%
df.shape
# Out:
# (7182, 5)

# %%
print(df.isnull().sum())
# Out:
# 2017-05-08 21:42:56+00:00    0
# p2.xlarge                    0
# Linux/UNIX                   0
# us-east-1b                   0
# 0.25                         0
# dtype: int64

# %%
df.head()
# Out:
#    2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b    0.25
# 0  2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 1  2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# 2  2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2500
# 3  2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 4  2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414

# %%
df=df.dropna(how='any', axis=0).dropna(how='any', axis=1)
df.isnull().sum()
# Out:
# 2017-05-08 21:42:56+00:00    0
# p2.xlarge                    0
# Linux/UNIX                   0
# us-east-1b                   0
# 0.25                         0
# dtype: int64

# %%
# Normalize the cost values
scaler = MinMaxScaler()
df['0.25'] = scaler.fit_transform(df[['0.25']])

# Create sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i + seq_length]
        y = data[i + seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 10
X, y = create_sequences(df['0.25'].values, seq_length)

# Reshape X to 3D array for LSTM input
X = X.reshape((X.shape[0], X.shape[1], 1))

# Split into training and validation sets
split_index = int(len(X) * 0.8)
X_train, X_val = X[:split_index], X[split_index:]
y_train, y_val = y[:split_index], y[split_index:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

# Build the LSTM model
model = Sequential()
model.add(Input(shape=(seq_length, 1)))  # Define input shape
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
# model.add(LSTM(50, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10, verbose=1)
# Out:
# Epoch 1/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.0062 - val_loss: 9.5201e-04
# Epoch 2/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0015 - val_loss: 3.8604e-04
# Epoch 3/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.0013 - val_loss: 2.4365e-04
# Epoch 4/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0012 - val_loss: 2.2556e-04
# Epoch 5/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0010 - val_loss: 3.1364e-04
# Epoch 6/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0011 - val_loss: 2.0837e-04
# Epoch 7/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 8.8783e-04 - val_loss: 1.6563e-04
# Epoch 8/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 9.1411e-04 - val_loss: 1.4106e-04
# Epoch 9/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 9.8875e-04 - val_loss: 1.8558e-04
# Epoch 10/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 7.7304e-04 - val_loss: 4.0642e-04
# Epoch 11/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 7.9340e-04 - val_loss: 1.7427e-04
# Epoch 12/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 9.3719e-04 - val_loss: 1.4782e-04
# Epoch 13/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 8.2741e-04 - val_loss: 2.1466e-04
# Epoch 14/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 8.5855e-04 - val_loss: 1.7378e-04
# Epoch 15/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 9.6937e-04 - val_loss: 1.3967e-04
# Epoch 16/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 8.1286e-04 - val_loss: 1.4657e-04
# Epoch 17/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - loss: 7.5680e-04 - val_loss: 2.1152e-04
# Epoch 18/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 9.8390e-04 - val_loss: 2.9248e-04
# Epoch 19/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 7.9330e-04 - val_loss: 1.3712e-04
# Epoch 20/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 7.4937e-04 - val_loss: 2.2496e-04
# Epoch 21/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 8.5643e-04 - val_loss: 2.0239e-04
# Epoch 22/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.4167e-04 - val_loss: 1.7361e-04
# Epoch 23/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 6.7692e-04 - val_loss: 2.0496e-04
# Epoch 24/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 8.2008e-04 - val_loss: 1.7381e-04
# Epoch 25/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 7.0209e-04 - val_loss: 1.7225e-04
# Epoch 26/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 7.9480e-04 - val_loss: 1.5119e-04
# Epoch 27/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 7.4725e-04 - val_loss: 2.2717e-04
# Epoch 28/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 8.3472e-04 - val_loss: 1.8211e-04
# Epoch 29/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 7.2917e-04 - val_loss: 1.6880e-04
# Epoch 30/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 8.1628e-04 - val_loss: 1.3600e-04
# Epoch 31/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.1744e-04 - val_loss: 1.4895e-04
# Epoch 32/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 7.6848e-04 - val_loss: 1.4324e-04
# Epoch 33/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 8.8789e-04 - val_loss: 2.6086e-04
# Epoch 34/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - loss: 7.7090e-04 - val_loss: 1.7371e-04
# Epoch 35/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - loss: 8.4614e-04 - val_loss: 1.6508e-04
# Epoch 36/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - loss: 7.8175e-04 - val_loss: 1.4673e-04
# Epoch 37/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 6.7931e-04 - val_loss: 1.5706e-04
# Epoch 38/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 7.2495e-04 - val_loss: 1.4804e-04
# Epoch 39/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 7.5119e-04 - val_loss: 1.3600e-04
# Epoch 40/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 8.5122e-04 - val_loss: 2.3127e-04
# Epoch 41/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 8.7157e-04 - val_loss: 1.7455e-04
# Epoch 42/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 7.9514e-04 - val_loss: 1.6514e-04
# Epoch 43/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.3399e-04 - val_loss: 1.5371e-04
# Epoch 44/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 6.8386e-04 - val_loss: 1.9007e-04
# Epoch 45/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 6.4705e-04 - val_loss: 1.9457e-04
# Epoch 46/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 7.1917e-04 - val_loss: 1.5074e-04
# Epoch 47/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 6.8176e-04 - val_loss: 1.3455e-04
# Epoch 48/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 6.6977e-04 - val_loss: 2.2247e-04
# Epoch 49/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 7.5465e-04 - val_loss: 1.3716e-04
# Epoch 50/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 7.5708e-04 - val_loss: 1.4398e-04
# Epoch 51/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.6044e-04 - val_loss: 2.1339e-04
# Epoch 52/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 6.7229e-04 - val_loss: 1.4924e-04
# Epoch 53/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.7237e-04 - val_loss: 1.7590e-04
# Epoch 54/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 8.3509e-04 - val_loss: 1.3402e-04
# Epoch 55/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 7.2300e-04 - val_loss: 1.6947e-04
# Epoch 56/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.6639e-04 - val_loss: 2.3417e-04
# Epoch 57/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 8.4194e-04 - val_loss: 3.1066e-04
# Epoch 58/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.1104e-04 - val_loss: 1.7202e-04
# Epoch 59/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.4596e-04 - val_loss: 1.8568e-04
# Epoch 60/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 8.3361e-04 - val_loss: 1.6397e-04
# Epoch 61/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 6.3596e-04 - val_loss: 1.5066e-04
# Epoch 62/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 0.0010 - val_loss: 1.5695e-04
# Epoch 63/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 6.7707e-04 - val_loss: 2.1739e-04
# Epoch 64/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.8691e-04 - val_loss: 1.5298e-04
# Epoch 65/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 9.0903e-04 - val_loss: 2.4913e-04
# Epoch 66/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 7.5301e-04 - val_loss: 2.1069e-04
# Epoch 67/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 6.2594e-04 - val_loss: 1.4055e-04
# Epoch 68/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.7570e-04 - val_loss: 1.6261e-04
# Epoch 69/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 6.2945e-04 - val_loss: 2.9884e-04
# Epoch 70/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 6.9024e-04 - val_loss: 1.5887e-04
# Epoch 71/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 7.9034e-04 - val_loss: 1.3269e-04
# Epoch 72/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 7.2204e-04 - val_loss: 1.4903e-04
# Epoch 73/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 6.9453e-04 - val_loss: 1.4852e-04
# Epoch 74/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 6.2089e-04 - val_loss: 1.4398e-04
# Epoch 75/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.7102e-04 - val_loss: 1.5425e-04
# Epoch 76/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.6735e-04 - val_loss: 1.3122e-04
# Epoch 77/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 6.5374e-04 - val_loss: 1.7220e-04
# Epoch 78/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 6.6045e-04 - val_loss: 1.5616e-04
# Epoch 79/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 6.9277e-04 - val_loss: 1.4371e-04
# Epoch 80/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 6.3092e-04 - val_loss: 2.4718e-04
# Epoch 81/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.9137e-04 - val_loss: 1.9199e-04
# Epoch 82/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 7.2048e-04 - val_loss: 2.0136e-04
# Epoch 83/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 7.2121e-04 - val_loss: 1.5805e-04
# Epoch 84/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 8.2314e-04 - val_loss: 1.4081e-04
# Epoch 85/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 7.7337e-04 - val_loss: 1.3700e-04
# Epoch 86/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.6411e-04 - val_loss: 1.4231e-04
# Epoch 87/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.6158e-04 - val_loss: 1.8048e-04
# Epoch 88/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 7.0813e-04 - val_loss: 1.7851e-04
# Epoch 89/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 8.9682e-04 - val_loss: 1.4424e-04
# Epoch 90/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.9355e-04 - val_loss: 1.6393e-04
# Epoch 91/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.6924e-04 - val_loss: 1.7859e-04
# Epoch 92/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.1072e-04 - val_loss: 1.7806e-04
# Epoch 93/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 6.4563e-04 - val_loss: 1.5783e-04
# Epoch 94/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.8959e-04 - val_loss: 1.7516e-04
# Epoch 95/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 7.4904e-04 - val_loss: 1.6098e-04
# Epoch 96/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 5.8790e-04 - val_loss: 1.7888e-04
# Epoch 97/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.8258e-04 - val_loss: 1.4771e-04
# Epoch 98/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 6.6556e-04 - val_loss: 1.6417e-04
# Epoch 99/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 7.8056e-04 - val_loss: 1.3195e-04
# Epoch 100/100
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 7.5652e-04 - val_loss: 1.4370e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,705 (373.85 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 63,804 (249.24 KB)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Make predictions on the validation set
y_pred = model.predict(X_val)

# Calculate evaluation metrics
mae = mean_absolute_error(y_val, y_pred)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# MAE: 0.005832723351543132
# MSE: 0.00014369740632900037
# RMSE: 0.01198738529993094

# %%
import matplotlib.pyplot as plt

# Predict the values for the training set
y_train_pred = model.predict(X_train)

# Reshape the predicted values to match the shape of the actual values
y_train_pred = y_train_pred.reshape(-1)

# Plot the predicted and actual values
plt.figure(figsize=(12, 6))
plt.plot(y_train, label='Actual Values')
plt.plot(y_train_pred, label='Predicted Values')
plt.xlabel('Date')
plt.ylabel('Cost')
plt.title('Actual vs Predicted AWS p2.xlarge Price in 10 Ecophs')
plt.legend()
plt.grid(True)
plt.tight_layout(pad=4.0)
plt.savefig('./Actual vs Predicted AWS p2.xlarge Price in 10 Ecophs.png')
plt.show()
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Number of folds
kf = KFold(n_splits=5, shuffle=True, random_state=42)

mae_scores = []
mse_scores = []
rmse_scores = []

for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Assuming your model is already defined as `model`
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    
    mae = mean_absolute_error(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    
    mae_scores.append(mae)
    mse_scores.append(mse)
    rmse_scores.append(rmse)

# Average scores
avg_mae = np.mean(mae_scores)
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)

print(f'Average MAE: {avg_mae:.2f}')
print(f'Average MSE: {avg_mse:.2f}')
print(f'Average RMSE: {avg_rmse:.2f}')
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 4.7809e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 5.2285e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 4.9264e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 6.0214e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 6.7920e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Average MAE: 0.01
# Average MSE: 0.00
# Average RMSE: 0.02

# %%
import matplotlib.pyplot as plt

# Plotting MAE, MSE, RMSE across folds
fig, ax = plt.subplots(3, 1, figsize=(10, 15))

ax[0].plot(range(1, len(mae_scores) + 1), mae_scores, marker='o')
ax[0].set_title('MAE Across Folds')
ax[0].set_xlabel('Fold Number')
ax[0].set_ylabel('MAE')

ax[1].plot(range(1, len(mse_scores) + 1), mse_scores, marker='o')
ax[1].set_title('MSE Across Folds')
ax[1].set_xlabel('Fold Number')
ax[1].set_ylabel('MSE')

ax[2].plot(range(1, len(rmse_scores) + 1), rmse_scores, marker='o')
ax[2].set_title('RMSE Across Folds')
ax[2].set_xlabel('Fold Number')
ax[2].set_ylabel('RMSE')

plt.suptitle('Evaluation Metrics Across Folds', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.tight_layout()
plt.savefig('./evaluation_metrics_across_folds 10 Ecophs.png')

plt.show()
