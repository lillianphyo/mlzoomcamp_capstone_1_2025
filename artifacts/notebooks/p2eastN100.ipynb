# %% [markdown]
# !pip install numpy pandas matplotlib seaborn keras tensorflow

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from sklearn.impute import SimpleImputer

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
import math
from sklearn.metrics import mean_squared_error
# Out:
# 2024-06-06 07:29:27.294474: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 07:29:27.301642: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 07:29:27.392616: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-06 07:29:29.349312: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# # Set the path to the directory containing the files
# path = '../data'

# # Create an empty list to store the names of the files
# files = []

# # Loop through all the files in the directory and add the file names to the list
# for file in os.listdir(path):
#     if file.endswith('.csv'):
#         files.append(os.path.join(path, file))

# # Use pandas to read all the files in the list into a single DataFrame
# df = pd.concat([pd.read_csv(file) for file in files], ignore_index=True)
df=pd.read_csv('../data/p2-east-1b.csv')
df.head
df.shape
# Out:
# (7182, 5)

# %%
df.head
# Out:
# <bound method NDFrame.head of       2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b    0.25
# 0     2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 1     2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# 2     2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2500
# 3     2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 4     2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# ...                         ...        ...         ...         ...     ...
# 7177  2017-04-26 15:26:03+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1613
# 7178  2017-04-26 15:25:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1610
# 7179  2017-04-26 15:23:21+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1616
# 7180  2017-04-26 15:22:21+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1623
# 7181  2017-04-26 15:21:19+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1620
#
# [7182 rows x 5 columns]>

# %%
df.shape
# Out:
# (7182, 5)

# %%
print(df.isnull().sum())
# Out:
# 2017-05-08 21:42:56+00:00    0
# p2.xlarge                    0
# Linux/UNIX                   0
# us-east-1b                   0
# 0.25                         0
# dtype: int64

# %%
df.head()
# Out:
#    2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b    0.25
# 0  2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 1  2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# 2  2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2500
# 3  2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 4  2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414

# %%
df=df.dropna(how='any', axis=0).dropna(how='any', axis=1)
df.isnull().sum()
# Out:
# 2017-05-08 21:42:56+00:00    0
# p2.xlarge                    0
# Linux/UNIX                   0
# us-east-1b                   0
# 0.25                         0
# dtype: int64

# %%
# Normalize the cost values
scaler = MinMaxScaler()
df['0.25'] = scaler.fit_transform(df[['0.25']])

# Create sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i + seq_length]
        y = data[i + seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 10
X, y = create_sequences(df['0.25'].values, seq_length)

# Reshape X to 3D array for LSTM input
X = X.reshape((X.shape[0], X.shape[1], 1))

# Split into training and validation sets
split_index = int(len(X) * 0.8)
X_train, X_val = X[:split_index], X[split_index:]
y_train, y_val = y[:split_index], y[split_index:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

# Build the LSTM model
model = Sequential()
model.add(Input(shape=(seq_length, 1)))  # Define input shape
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
# model.add(LSTM(50, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=100, verbose=1)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 0.0136 - val_loss: 5.4086e-04
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0016 - val_loss: 4.6354e-04
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0019 - val_loss: 4.4387e-04
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0015 - val_loss: 4.6324e-04
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0015 - val_loss: 4.1065e-04
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0013 - val_loss: 4.8295e-04
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0014 - val_loss: 3.4786e-04
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0015 - val_loss: 3.2826e-04
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0014 - val_loss: 2.8972e-04
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0013 - val_loss: 2.9406e-04
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0012 - val_loss: 3.1446e-04
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0012 - val_loss: 2.5234e-04
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.6923e-04 - val_loss: 4.1842e-04
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0011 - val_loss: 3.3863e-04
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0011 - val_loss: 2.1992e-04
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0010 - val_loss: 2.0749e-04
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 9.5015e-04 - val_loss: 2.0644e-04
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.7507e-04 - val_loss: 2.0396e-04
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 9.0080e-04 - val_loss: 2.1823e-04
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0010 - val_loss: 1.9565e-04
# Epoch 21/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 8.7076e-04 - val_loss: 2.5556e-04
# Epoch 22/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 8.7385e-04 - val_loss: 2.5854e-04
# Epoch 23/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 8.6937e-04 - val_loss: 2.6197e-04
# Epoch 24/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.1862e-04 - val_loss: 1.6502e-04
# Epoch 25/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 9.2387e-04 - val_loss: 1.6627e-04
# Epoch 26/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.6751e-04 - val_loss: 1.7069e-04
# Epoch 27/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 9.2630e-04 - val_loss: 1.8110e-04
# Epoch 28/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.8232e-04 - val_loss: 1.5753e-04
# Epoch 29/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.9305e-04 - val_loss: 1.7796e-04
# Epoch 30/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 8.2103e-04 - val_loss: 1.5103e-04
# Epoch 31/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.5615e-04 - val_loss: 1.4834e-04
# Epoch 32/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.8377e-04 - val_loss: 2.4817e-04
# Epoch 33/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 7.1621e-04 - val_loss: 1.7080e-04
# Epoch 34/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.9567e-04 - val_loss: 1.6297e-04
# Epoch 35/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 8.8173e-04 - val_loss: 1.4763e-04
# Epoch 36/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.7615e-04 - val_loss: 1.4406e-04
# Epoch 37/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.8231e-04 - val_loss: 1.5704e-04
# Epoch 38/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 6.8660e-04 - val_loss: 1.6149e-04
# Epoch 39/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.6365e-04 - val_loss: 1.7615e-04
# Epoch 40/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.5859e-04 - val_loss: 1.8364e-04
# Epoch 41/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 6.2106e-04 - val_loss: 1.4213e-04
# Epoch 42/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 7.4713e-04 - val_loss: 1.6131e-04
# Epoch 43/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.6309e-04 - val_loss: 1.6702e-04
# Epoch 44/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.6452e-04 - val_loss: 1.7351e-04
# Epoch 45/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2973e-04 - val_loss: 1.6173e-04
# Epoch 46/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 7.3358e-04 - val_loss: 1.8452e-04
# Epoch 47/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 7.9142e-04 - val_loss: 1.4224e-04
# Epoch 48/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 6.6570e-04 - val_loss: 1.4402e-04
# Epoch 49/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.3103e-04 - val_loss: 1.6218e-04
# Epoch 50/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 7.3787e-04 - val_loss: 2.9362e-04
# Epoch 51/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.1843e-04 - val_loss: 1.9902e-04
# Epoch 52/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 7.2792e-04 - val_loss: 1.6316e-04
# Epoch 53/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 6.7051e-04 - val_loss: 1.4945e-04
# Epoch 54/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.3478e-04 - val_loss: 2.3216e-04
# Epoch 55/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.2476e-04 - val_loss: 1.8957e-04
# Epoch 56/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 7.5404e-04 - val_loss: 1.7220e-04
# Epoch 57/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 7.0369e-04 - val_loss: 1.4558e-04
# Epoch 58/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.5695e-04 - val_loss: 1.5514e-04
# Epoch 59/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 6.7577e-04 - val_loss: 1.6971e-04
# Epoch 60/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 6.2349e-04 - val_loss: 1.4325e-04
# Epoch 61/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 6.3226e-04 - val_loss: 1.4969e-04
# Epoch 62/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.6952e-04 - val_loss: 1.3914e-04
# Epoch 63/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 7.2042e-04 - val_loss: 1.5610e-04
# Epoch 64/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 7.1260e-04 - val_loss: 1.4723e-04
# Epoch 65/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.4803e-04 - val_loss: 1.7977e-04
# Epoch 66/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.2568e-04 - val_loss: 1.5765e-04
# Epoch 67/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 6.7031e-04 - val_loss: 1.4504e-04
# Epoch 68/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 6.4767e-04 - val_loss: 1.5440e-04
# Epoch 69/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.3675e-04 - val_loss: 1.8201e-04
# Epoch 70/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.3515e-04 - val_loss: 1.3933e-04
# Epoch 71/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 7.0145e-04 - val_loss: 1.5850e-04
# Epoch 72/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.3319e-04 - val_loss: 1.3747e-04
# Epoch 73/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.9276e-04 - val_loss: 2.1080e-04
# Epoch 74/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.6673e-04 - val_loss: 1.4105e-04
# Epoch 75/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.9767e-04 - val_loss: 1.6536e-04
# Epoch 76/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 6.4999e-04 - val_loss: 1.5401e-04
# Epoch 77/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.5743e-04 - val_loss: 1.6131e-04
# Epoch 78/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.3181e-04 - val_loss: 1.4021e-04
# Epoch 79/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.0978e-04 - val_loss: 1.3844e-04
# Epoch 80/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.2626e-04 - val_loss: 1.9226e-04
# Epoch 81/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.0396e-04 - val_loss: 1.9090e-04
# Epoch 82/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.4318e-04 - val_loss: 1.4709e-04
# Epoch 83/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.8411e-04 - val_loss: 1.9092e-04
# Epoch 84/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.4598e-04 - val_loss: 1.3914e-04
# Epoch 85/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 6.4435e-04 - val_loss: 1.5724e-04
# Epoch 86/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 5.5579e-04 - val_loss: 1.5939e-04
# Epoch 87/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.0339e-04 - val_loss: 1.8136e-04
# Epoch 88/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.5236e-04 - val_loss: 1.4321e-04
# Epoch 89/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 7.0442e-04 - val_loss: 3.2499e-04
# Epoch 90/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.1925e-04 - val_loss: 1.4946e-04
# Epoch 91/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.9734e-04 - val_loss: 2.2837e-04
# Epoch 92/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 6.6522e-04 - val_loss: 1.4501e-04
# Epoch 93/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 6.9421e-04 - val_loss: 1.6200e-04
# Epoch 94/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.1998e-04 - val_loss: 1.3951e-04
# Epoch 95/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 6.1056e-04 - val_loss: 1.6747e-04
# Epoch 96/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 6.3571e-04 - val_loss: 1.4041e-04
# Epoch 97/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.8611e-04 - val_loss: 1.4584e-04
# Epoch 98/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.0163e-04 - val_loss: 1.8719e-04
# Epoch 99/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 7.4174e-04 - val_loss: 1.4240e-04
# Epoch 100/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 7.7580e-04 - val_loss: 1.7690e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,705 (373.85 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 63,804 (249.24 KB)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Make predictions on the validation set
y_pred = model.predict(X_val)

# Calculate evaluation metrics
mae = mean_absolute_error(y_val, y_pred)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# MAE: 0.008432512060456943
# MSE: 0.00017689856155525557
# RMSE: 0.013300321859085048

# %%
import matplotlib.pyplot as plt

# Predict the values for the training set
y_train_pred = model.predict(X_train)

# Reshape the predicted values to match the shape of the actual values
y_train_pred = y_train_pred.reshape(-1)

# Plot the predicted and actual values
plt.figure(figsize=(12, 6))
plt.plot(y_train, label='Actual Values')
plt.plot(y_train_pred, label='Predicted Values')
plt.xlabel('Date')
plt.ylabel('Cost')
plt.title('Actual vs Predicted AWS p2.xlarge Price in 100 Ecophs')
plt.legend()
plt.grid(True)
plt.tight_layout(pad=4.0)
plt.savefig('./Actual vs Predicted AWS p2.xlarge Price in 100 Ecophs.png')
plt.show()
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Number of folds
kf = KFold(n_splits=5, shuffle=True, random_state=42)

mae_scores = []
mse_scores = []
rmse_scores = []

for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Assuming your model is already defined as `model`
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    
    mae = mean_absolute_error(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    
    mae_scores.append(mae)
    mse_scores.append(mse)
    rmse_scores.append(rmse)

# Average scores
avg_mae = np.mean(mae_scores)
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)

print(f'Average MAE: {avg_mae:.2f}')
print(f'Average MSE: {avg_mse:.2f}')
print(f'Average RMSE: {avg_rmse:.2f}')
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 6.5350e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 7.7549e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 6.1615e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 5.8362e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 6.6915e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Average MAE: 0.01
# Average MSE: 0.00
# Average RMSE: 0.02

# %%
import matplotlib.pyplot as plt

# Plotting MAE, MSE, RMSE across folds
fig, ax = plt.subplots(3, 1, figsize=(10, 15))

ax[0].plot(range(1, len(mae_scores) + 1), mae_scores, marker='o')
ax[0].set_title('MAE Across Folds')
ax[0].set_xlabel('Fold Number')
ax[0].set_ylabel('MAE')

ax[1].plot(range(1, len(mse_scores) + 1), mse_scores, marker='o')
ax[1].set_title('MSE Across Folds')
ax[1].set_xlabel('Fold Number')
ax[1].set_ylabel('MSE')

ax[2].plot(range(1, len(rmse_scores) + 1), rmse_scores, marker='o')
ax[2].set_title('RMSE Across Folds')
ax[2].set_xlabel('Fold Number')
ax[2].set_ylabel('RMSE')

plt.suptitle('Evaluation Metrics Across Folds', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.tight_layout()
plt.savefig('./evaluation_metrics_across_folds 100 Ecophs.png')

plt.show()
