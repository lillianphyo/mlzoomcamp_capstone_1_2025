# %% [markdown]
# !pip install numpy pandas matplotlib seaborn keras tensorflow

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from sklearn.impute import SimpleImputer

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
import math
from sklearn.metrics import mean_squared_error
# Out:
# 2024-06-06 07:24:39.436388: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 07:24:39.441778: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 07:24:39.511543: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-06 07:24:41.633013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# # Set the path to the directory containing the files
# path = '../data'

# # Create an empty list to store the names of the files
# files = []

# # Loop through all the files in the directory and add the file names to the list
# for file in os.listdir(path):
#     if file.endswith('.csv'):
#         files.append(os.path.join(path, file))

# # Use pandas to read all the files in the list into a single DataFrame
# df = pd.concat([pd.read_csv(file) for file in files], ignore_index=True)
df=pd.read_csv('../data/p2-east-1b.csv')
df.head
df.shape
# Out:
# (7182, 5)

# %%
df.head
# Out:
# <bound method NDFrame.head of       2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b    0.25
# 0     2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 1     2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# 2     2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2500
# 3     2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 4     2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# ...                         ...        ...         ...         ...     ...
# 7177  2017-04-26 15:26:03+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1613
# 7178  2017-04-26 15:25:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1610
# 7179  2017-04-26 15:23:21+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1616
# 7180  2017-04-26 15:22:21+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1623
# 7181  2017-04-26 15:21:19+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.1620
#
# [7182 rows x 5 columns]>

# %%
df.shape
# Out:
# (7182, 5)

# %%
print(df.isnull().sum())
# Out:
# 2017-05-08 21:42:56+00:00    0
# p2.xlarge                    0
# Linux/UNIX                   0
# us-east-1b                   0
# 0.25                         0
# dtype: int64

# %%
df.head()
# Out:
#    2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b    0.25
# 0  2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 1  2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414
# 2  2017-05-08 21:42:56+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2500
# 3  2017-05-08 21:41:01+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2402
# 4  2017-05-08 21:40:05+00:00  p2.xlarge  Linux/UNIX  us-east-1b  0.2414

# %%
df=df.dropna(how='any', axis=0).dropna(how='any', axis=1)
df.isnull().sum()
# Out:
# 2017-05-08 21:42:56+00:00    0
# p2.xlarge                    0
# Linux/UNIX                   0
# us-east-1b                   0
# 0.25                         0
# dtype: int64

# %%
# Normalize the cost values
scaler = MinMaxScaler()
df['0.25'] = scaler.fit_transform(df[['0.25']])

# Create sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i + seq_length]
        y = data[i + seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 10
X, y = create_sequences(df['0.25'].values, seq_length)

# Reshape X to 3D array for LSTM input
X = X.reshape((X.shape[0], X.shape[1], 1))

# Split into training and validation sets
split_index = int(len(X) * 0.8)
X_train, X_val = X[:split_index], X[split_index:]
y_train, y_val = y[:split_index], y[split_index:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

# Build the LSTM model
model = Sequential()
model.add(Input(shape=(seq_length, 1)))  # Define input shape
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
# model.add(LSTM(50, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=20, verbose=1)
# Out:
# Epoch 1/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - loss: 0.0081 - val_loss: 4.5388e-04
# Epoch 2/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0016 - val_loss: 3.9944e-04
# Epoch 3/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0013 - val_loss: 3.1723e-04
# Epoch 4/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0014 - val_loss: 3.9052e-04
# Epoch 5/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.0015e-04
# Epoch 6/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0013 - val_loss: 5.5684e-04
# Epoch 7/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0011 - val_loss: 2.1431e-04
# Epoch 8/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0010 - val_loss: 1.5699e-04
# Epoch 9/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0010 - val_loss: 1.6852e-04
# Epoch 10/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 9.4963e-04 - val_loss: 1.6262e-04
# Epoch 11/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.2779e-04 - val_loss: 2.8755e-04
# Epoch 12/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 8.0437e-04 - val_loss: 2.1523e-04
# Epoch 13/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 8.2990e-04 - val_loss: 2.6631e-04
# Epoch 14/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 7.3337e-04 - val_loss: 3.0182e-04
# Epoch 15/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 8.5203e-04 - val_loss: 2.0019e-04
# Epoch 16/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 8.6987e-04 - val_loss: 1.3809e-04
# Epoch 17/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 7.8827e-04 - val_loss: 2.3023e-04
# Epoch 18/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 8.6104e-04 - val_loss: 1.4334e-04
# Epoch 19/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 7.4290e-04 - val_loss: 1.4807e-04
# Epoch 20/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 7.9992e-04 - val_loss: 3.1785e-04
# Epoch 21/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 7.3631e-04 - val_loss: 1.8301e-04
# Epoch 22/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 8.4431e-04 - val_loss: 1.8271e-04
# Epoch 23/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 6.9925e-04 - val_loss: 2.4771e-04
# Epoch 24/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.9993e-04 - val_loss: 1.9382e-04
# Epoch 25/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 8.4495e-04 - val_loss: 2.3997e-04
# Epoch 26/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 7.0685e-04 - val_loss: 1.3799e-04
# Epoch 27/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0010 - val_loss: 1.8663e-04
# Epoch 28/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.3268e-04 - val_loss: 1.7584e-04
# Epoch 29/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.8610e-04 - val_loss: 2.3529e-04
# Epoch 30/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 8.9623e-04 - val_loss: 1.3867e-04
# Epoch 31/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.4185e-04 - val_loss: 1.4779e-04
# Epoch 32/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.6763e-04 - val_loss: 1.7616e-04
# Epoch 33/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 8.1069e-04 - val_loss: 1.7306e-04
# Epoch 34/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.4634e-04 - val_loss: 1.4492e-04
# Epoch 35/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 8.0689e-04 - val_loss: 1.5344e-04
# Epoch 36/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 6.9303e-04 - val_loss: 1.6397e-04
# Epoch 37/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 9.2918e-04 - val_loss: 1.7745e-04
# Epoch 38/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 7.4207e-04 - val_loss: 1.4620e-04
# Epoch 39/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 6.7497e-04 - val_loss: 2.0510e-04
# Epoch 40/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 8.1941e-04 - val_loss: 1.8953e-04
# Epoch 41/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 8.5722e-04 - val_loss: 1.4917e-04
# Epoch 42/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 7.9372e-04 - val_loss: 1.5305e-04
# Epoch 43/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.3046e-04 - val_loss: 2.2660e-04
# Epoch 44/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 6.8861e-04 - val_loss: 1.6311e-04
# Epoch 45/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 6.3367e-04 - val_loss: 1.4279e-04
# Epoch 46/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 8.2602e-04 - val_loss: 1.3603e-04
# Epoch 47/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.5949e-04 - val_loss: 1.4243e-04
# Epoch 48/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 7.3417e-04 - val_loss: 1.5208e-04
# Epoch 49/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.1333e-04 - val_loss: 1.7493e-04
# Epoch 50/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.9449e-04 - val_loss: 1.9385e-04
# Epoch 51/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 7.1696e-04 - val_loss: 1.5597e-04
# Epoch 52/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 8.0364e-04 - val_loss: 1.9489e-04
# Epoch 53/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 6.8879e-04 - val_loss: 1.4961e-04
# Epoch 54/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 6.6910e-04 - val_loss: 1.9507e-04
# Epoch 55/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 7.2630e-04 - val_loss: 1.3236e-04
# Epoch 56/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 7.4295e-04 - val_loss: 1.5748e-04
# Epoch 57/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 7.3114e-04 - val_loss: 1.5359e-04
# Epoch 58/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 7.3406e-04 - val_loss: 1.4564e-04
# Epoch 59/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 6.4072e-04 - val_loss: 2.2707e-04
# Epoch 60/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 6.5483e-04 - val_loss: 1.6576e-04
# Epoch 61/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 7.4356e-04 - val_loss: 1.9761e-04
# Epoch 62/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 6.7729e-04 - val_loss: 1.8687e-04
# Epoch 63/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 6.6896e-04 - val_loss: 1.5915e-04
# Epoch 64/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.5408e-04 - val_loss: 3.0047e-04
# Epoch 65/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 7.2302e-04 - val_loss: 1.4008e-04
# Epoch 66/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 6.3177e-04 - val_loss: 2.9454e-04
# Epoch 67/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.2201e-04 - val_loss: 1.4823e-04
# Epoch 68/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 6.7553e-04 - val_loss: 1.3434e-04
# Epoch 69/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 6.9210e-04 - val_loss: 1.4280e-04
# Epoch 70/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.1246e-04 - val_loss: 1.3900e-04
# Epoch 71/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.5689e-04 - val_loss: 1.4270e-04
# Epoch 72/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 7.9149e-04 - val_loss: 1.4703e-04
# Epoch 73/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 6.9592e-04 - val_loss: 1.3324e-04
# Epoch 74/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.9789e-04 - val_loss: 1.4134e-04
# Epoch 75/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.4660e-04 - val_loss: 1.3325e-04
# Epoch 76/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.3483e-04 - val_loss: 1.7482e-04
# Epoch 77/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.2333e-04 - val_loss: 2.1018e-04
# Epoch 78/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.1288e-04 - val_loss: 1.7649e-04
# Epoch 79/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 6.6936e-04 - val_loss: 1.7717e-04
# Epoch 80/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.3459e-04 - val_loss: 1.3626e-04
# Epoch 81/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 7.5640e-04 - val_loss: 1.5395e-04
# Epoch 82/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 6.8806e-04 - val_loss: 1.3855e-04
# Epoch 83/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 7.0979e-04 - val_loss: 1.4047e-04
# Epoch 84/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 6.6281e-04 - val_loss: 1.3504e-04
# Epoch 85/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 5.8576e-04 - val_loss: 1.8778e-04
# Epoch 86/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.4155e-04 - val_loss: 1.4275e-04
# Epoch 87/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 9.5652e-04 - val_loss: 1.8071e-04
# Epoch 88/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 7.6324e-04 - val_loss: 1.8926e-04
# Epoch 89/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - loss: 6.0539e-04 - val_loss: 1.3156e-04
# Epoch 90/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 6.5224e-04 - val_loss: 2.2568e-04
# Epoch 91/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 8.0788e-04 - val_loss: 1.4526e-04
# Epoch 92/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 6.9410e-04 - val_loss: 1.4040e-04
# Epoch 93/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.4492e-04 - val_loss: 1.3864e-04
# Epoch 94/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 7.4457e-04 - val_loss: 1.3605e-04
# Epoch 95/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 5.8777e-04 - val_loss: 1.4043e-04
# Epoch 96/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 6.6828e-04 - val_loss: 2.5058e-04
# Epoch 97/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 8.2956e-04 - val_loss: 1.3589e-04
# Epoch 98/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 5.4444e-04 - val_loss: 1.8749e-04
# Epoch 99/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 7.6944e-04 - val_loss: 1.4377e-04
# Epoch 100/100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 6.6689e-04 - val_loss: 1.9307e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,705 (373.85 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 63,804 (249.24 KB)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Make predictions on the validation set
y_pred = model.predict(X_val)

# Calculate evaluation metrics
mae = mean_absolute_error(y_val, y_pred)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# MAE: 0.009259775191586666
# MSE: 0.00019306680408438196
# RMSE: 0.013894848113037506

# %%
import matplotlib.pyplot as plt

# Predict the values for the training set
y_train_pred = model.predict(X_train)

# Reshape the predicted values to match the shape of the actual values
y_train_pred = y_train_pred.reshape(-1)

# Plot the predicted and actual values
plt.figure(figsize=(12, 6))
plt.plot(y_train, label='Actual Values')
plt.plot(y_train_pred, label='Predicted Values')
plt.xlabel('Date')
plt.ylabel('Cost')
plt.title('Actual vs Predicted AWS p2.xlarge Price in 20 Ecophs')
plt.legend()
plt.grid(True)
plt.tight_layout(pad=4.0)
plt.savefig('./Actual vs Predicted AWS p2.xlarge Price in 20 Ecophs.png')
plt.show()
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Number of folds
kf = KFold(n_splits=5, shuffle=True, random_state=42)

mae_scores = []
mse_scores = []
rmse_scores = []

for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Assuming your model is already defined as `model`
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    
    mae = mean_absolute_error(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    
    mae_scores.append(mae)
    mse_scores.append(mse)
    rmse_scores.append(rmse)

# Average scores
avg_mae = np.mean(mae_scores)
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)

print(f'Average MAE: {avg_mae:.2f}')
print(f'Average MSE: {avg_mse:.2f}')
print(f'Average RMSE: {avg_rmse:.2f}')
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 5.5585e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 5.3559e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.7493e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 4.3396e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.8452e-04
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Average MAE: 0.01
# Average MSE: 0.00
# Average RMSE: 0.02

# %%
import matplotlib.pyplot as plt

# Plotting MAE, MSE, RMSE across folds
fig, ax = plt.subplots(3, 1, figsize=(10, 15))

ax[0].plot(range(1, len(mae_scores) + 1), mae_scores, marker='o')
ax[0].set_title('MAE Across Folds')
ax[0].set_xlabel('Fold Number')
ax[0].set_ylabel('MAE')

ax[1].plot(range(1, len(mse_scores) + 1), mse_scores, marker='o')
ax[1].set_title('MSE Across Folds')
ax[1].set_xlabel('Fold Number')
ax[1].set_ylabel('MSE')

ax[2].plot(range(1, len(rmse_scores) + 1), rmse_scores, marker='o')
ax[2].set_title('RMSE Across Folds')
ax[2].set_xlabel('Fold Number')
ax[2].set_ylabel('RMSE')

plt.suptitle('Evaluation Metrics Across Folds', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.tight_layout()
plt.savefig('./evaluation_metrics_across_folds 20 Ecophs.png')

plt.show()
